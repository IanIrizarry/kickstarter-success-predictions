# %% [markdown]
# # Capstone Project

# %% [markdown]
# ## Goal

# %% [markdown]
# The goal of this project is to use predictive analytics to determine what will make it more likely to have a successful Kickstarter based on historical data. The historical data tells us which projects were successful and which projects were not.

# %% [markdown]
# https://www.kickstarter.com/help/handbook/funding
#
# Kickstarter provides what is called a creator's handbook for funding. The original objective of this analysis was to determine what leads to successful boardgames. From there the idea was to create a boardgame based on my findings to see if I could create a successful boardgame based on the findings. However, an important first phase of this analysis was to see if I could predict whether or not a project would be successful. So that is what I did here.

# %% [markdown]
# ## Import Libraries

# %%
import os
import glob
import pandas as pd
# os.chdir("./datasets/kickstarter_data/") # uncomment to run initially

import re
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV
from sklearn.preprocessing import PolynomialFeatures, PowerTransformer
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from sklearn.metrics import r2_score

# %matplotlib inline

# %% [markdown]
# ## Gather Data

# %% [markdown]
# Data came from:
# https://webrobots.io/kickstarter-datasets/

# %% [markdown]
# ## Combine Data

# %% [markdown]
# The cell below should only be ran one time. The code

# %%
## uncomment to run initially
## credit: https://www.freecodecamp.org/news/how-to-combine-multiple-csv-files-with-8-lines-of-code-265183e0854/
# extension = 'csv'
# all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# #combine all files in the list
# combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# #export to csv
# combined_csv.to_csv( "combined.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# ## Read in Data

# %%
df = pd.read_csv('./datasets/kickstarter_data/combined.csv')

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
pd.set_option('display.max_rows', 9999)
pd.set_option('display.max_columns', 9999)
pd.set_option('display.width', 9999)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 217006 entries, 0 to 217432
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   backers_count             217006 non-null  int64
#  1   blurb                     217006 non-null  object
#  2   category                  217006 non-null  object
#  3   converted_pledged_amount  217006 non-null  int64
#  4   country                   217006 non-null  object
#  5   country_displayable_name  217006 non-null  object
#  6   created_at                217006 non-null  int64
#  7   creator                   217006 non-null  object
#  8   currency                  217006 non-null  object
#  9   currency_symbol           217006 non-null  object
#  10  currency_trailing_code    217006 non-null  bool
#  11  current_currency          217006 non-null  object
#  12  deadline                  217006 non-null  int64
#  13  disable_communication     217006 non-null  bool
#  14  fx_rate                   217006 non-null  float64
#  15  goal                      217006 non-null  float64
#  16  id                        217006 non-null  int64
#  17  is_starrable              217006 non-null  bool
#  18  launched_at               217006 non-null  int64
#  19  location                  217006 non-null  object
#  20  name                      217006 non-null  object
#  21  photo                     217006 non-null  object
#  22  pledged                   217006 non-null  float64
#  23  profile                   217006 non-null  object
#  24  slug                      217006 non-null  object
#  25  source_url                217006 non-null  object
#  26  spotlight                 217006 non-null  bool
#  27  staff_pick                217006 non-null  bool
#  28  state                     217006 non-null  object
#  29  state_changed_at          217006 non-null  int64
#  30  static_usd_rate           217006 non-null  float64
#  31  urls                      217006 non-null  object
#  32  usd_pledged               217006 non-null  float64
#  33  usd_type                  217006 non-null  object
# dtypes: bool(5), float64(5), int64(7), object(17)
# memory usage: 60.7+ MB

# %%
df.describe()
# Out:
#        backers_count  converted_pledged_amount    created_at      deadline  \
# count  217433.000000              2.174330e+05  2.174330e+05  2.174330e+05
# mean      153.312377              1.391486e+04  1.475045e+09  1.482085e+09
# std       955.465580              1.115873e+05  7.325189e+07  7.297742e+07
# min         0.000000              0.000000e+00  1.240366e+09  1.242468e+09
# 25%         4.000000              1.250000e+02  1.422421e+09  1.428688e+09
# 50%        29.000000              1.632000e+03  1.476545e+09  1.483462e+09
# 75%        93.000000              6.820000e+03  1.540860e+09  1.549209e+09
# max    105857.000000              1.296961e+07  1.589423e+09  1.594600e+09
#
#              fx_rate          goal            id   launched_at       pledged  \
# count  217433.000000  2.174330e+05  2.174330e+05  2.174330e+05  2.174330e+05
# mean        0.972468  5.086400e+04  1.073505e+09  1.479240e+09  2.528557e+04
# std         0.224465  1.225217e+06  6.194085e+08  7.298511e+07  9.149154e+05
# min         0.009327  1.000000e-02  1.852000e+04  1.240674e+09  0.000000e+00
# 25%         1.000000  1.500000e+03  5.369538e+08  1.425783e+09  1.300000e+02
# 50%         1.000000  5.000000e+03  1.073543e+09  1.480562e+09  1.677000e+03
# 75%         1.000000  1.500000e+04  1.610309e+09  1.546381e+09  7.340000e+03
# max         9.464383  1.000000e+08  2.147476e+09  1.589431e+09  2.353205e+08
#
#        state_changed_at  static_usd_rate   usd_pledged
# count      2.174330e+05    217433.000000  2.174330e+05
# mean       1.481932e+09         1.001734  1.391928e+04
# std        7.287333e+07         0.239715  1.115837e+05
# min        1.242468e+09         0.008771  0.000000e+00
# 25%        1.428555e+09         1.000000  1.250000e+02
# 50%        1.483387e+09         1.000000  1.633220e+03
# 75%        1.549132e+09         1.000000  6.833000e+03
# max        1.589432e+09         1.716408  1.296961e+07

# %% [markdown]
# ### Missing Data

# %%
missing_values= df.isnull().sum()
missing_values/len(df)
missing_values.sort_values(ascending=False)
# Out:
# is_backing                  217361
# permissions                 217361
# friends                     217361
# is_starred                  217361
# location                       215
# usd_type                       204
# blurb                            8
# staff_pick                       0
# spotlight                        0
# category                         0
# converted_pledged_amount         0
# country                          0
# country_displayable_name         0
# created_at                       0
# creator                          0
# currency                         0
# currency_symbol                  0
# currency_trailing_code           0
# current_currency                 0
# deadline                         0
# disable_communication            0
# urls                             0
# fx_rate                          0
# goal                             0
# id                               0
# usd_pledged                      0
# is_starrable                     0
# static_usd_rate                  0
# launched_at                      0
# state_changed_at                 0
# name                             0
# state                            0
# photo                            0
# pledged                          0
# profile                          0
# slug                             0
# source_url                       0
# backers_count                    0
# dtype: int64

# %% [markdown]
# ### Resolve Missing Values

# %%
# drop these features due to having a significant number of missing values
df.drop([
    'friends',
    'is_backing',
    'is_starred',
    'permissions'
], axis=1, inplace=True)

# %%
# eliminate remaining missing values
df.dropna(inplace=True)

# %%
# verify missing values were resolved
missing_values= df.isnull().sum()
missing_values/len(df)
missing_values.sort_values(ascending=False)
# Out:
# usd_type                    0
# currency                    0
# fx_rate                     0
# disable_communication       0
# deadline                    0
# current_currency            0
# currency_trailing_code      0
# currency_symbol             0
# creator                     0
# usd_pledged                 0
# created_at                  0
# country_displayable_name    0
# country                     0
# converted_pledged_amount    0
# category                    0
# blurb                       0
# goal                        0
# id                          0
# is_starrable                0
# launched_at                 0
# location                    0
# name                        0
# photo                       0
# pledged                     0
# profile                     0
# slug                        0
# source_url                  0
# spotlight                   0
# staff_pick                  0
# state                       0
# state_changed_at            0
# static_usd_rate             0
# urls                        0
# backers_count               0
# dtype: int64

# %% [markdown]
# ### Re-Explore Data

# %%
df.head()
# Out:
#    backers_count                                              blurb  \
# 0              1  we are going Production herbal teabag of  plan...
# 1            637  Two agents battle each other in another dimens...
# 2             50  A collection of Hard Enamel pins inspired by T...
# 3              8  Low carb, no sugar sauces and marinades using ...
# 4           6452  The everyday bag fused with Parisian chic and ...
#
#                                             category  \
# 0  {"id":313,"name":"Small Batch","slug":"food/sm...
# 1  {"id":34,"name":"Tabletop Games","slug":"games...
# 2  {"id":262,"name":"Accessories","slug":"fashion...
# 3  {"id":313,"name":"Small Batch","slug":"food/sm...
# 4  {"id":28,"name":"Product Design","slug":"desig...
#
#    converted_pledged_amount country country_displayable_name  created_at  \
# 0                        19      AU                Australia  1441269202
# 1                     16233      US        the United States  1576048498
# 2                       983      CA                   Canada  1560821709
# 3                       361      US        the United States  1563139848
# 4                   1385803      US        the United States  1561364892
#
#                                              creator currency currency_symbol  \
# 0  {"id":1555219532,"name":"ehsan","is_registered...      AUD               $
# 1  {"id":99575233,"name":"David Gerrard","is_regi...      USD               $
# 2  {"id":1855173855,"name":"Caitlin Peters","slug...      CAD               $
# 3  {"id":1148188586,"name":"Ian","slug":"penningt...      USD               $
# 4  {"id":1085606247,"name":"Laflore","slug":"bobo...      USD               $
#
#    ...                                               slug  \
# 0  ...  production-herbal-teabag-of-plants-native-to-iran
# 1  ...                                      slip-strike-0
# 2  ...                                  tattoo-shop-flash
# 3  ...              penningtons-keto-sauces-and-marinades
# 4  ...          bobobark-designed-for-women-made-for-life
#
#                                           source_url  spotlight  staff_pick  \
# 0  https://www.kickstarter.com/discover/categorie...      False       False
# 1  https://www.kickstarter.com/discover/categorie...       True       False
# 2  https://www.kickstarter.com/discover/categorie...       True       False
# 3  https://www.kickstarter.com/discover/categorie...      False       False
# 4  https://www.kickstarter.com/discover/categorie...       True       False
#
#         state  state_changed_at  static_usd_rate  \
# 0      failed        1444141184         0.691164
# 1  successful        1583987400         1.000000
# 2  successful        1564165825         0.762900
# 3      failed        1569530544         1.000000
# 4  successful        1568408340         1.000000
#
#                                                 urls   usd_pledged  usd_type
# 0  {"web":{"project":"https://www.kickstarter.com...  1.866144e+01  domestic
# 1  {"web":{"project":"https://www.kickstarter.com...  1.623300e+04  domestic
# 2  {"web":{"project":"https://www.kickstarter.com...  9.874137e+02  domestic
# 3  {"web":{"project":"https://www.kickstarter.com...  3.610000e+02  domestic
# 4  {"web":{"project":"https://www.kickstarter.com...  1.385803e+06  domestic
#
# [5 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['backers_count', 'blurb', 'category', 'converted_pledged_amount',
#        'country', 'country_displayable_name', 'created_at', 'creator',
#        'currency', 'currency_symbol', 'currency_trailing_code',
#        'current_currency', 'deadline', 'disable_communication', 'fx_rate',
#        'goal', 'id', 'is_starrable', 'launched_at', 'location', 'name',
#        'photo', 'pledged', 'profile', 'slug', 'source_url', 'spotlight',
#        'staff_pick', 'state', 'state_changed_at', 'static_usd_rate', 'urls',
#        'usd_pledged', 'usd_type'],
#       dtype='object')

# %%
df.describe()
# Out:
#        backers_count  converted_pledged_amount    created_at      deadline  \
# count  217006.000000              2.170060e+05  2.170060e+05  2.170060e+05
# mean      153.397791              1.391843e+04  1.475155e+09  1.482196e+09
# std       956.261442              1.116707e+05  7.296200e+07  7.268108e+07
# min         0.000000              0.000000e+00  1.240366e+09  1.242468e+09
# 25%         4.000000              1.250000e+02  1.422486e+09  1.428764e+09
# 50%        29.000000              1.630000e+03  1.476549e+09  1.483467e+09
# 75%        93.000000              6.818000e+03  1.540804e+09  1.549072e+09
# max    105857.000000              1.296961e+07  1.589423e+09  1.594600e+09
#
#              fx_rate          goal            id   launched_at       pledged  \
# count  217006.000000  2.170060e+05  2.170060e+05  2.170060e+05  2.170060e+05
# mean        0.971724  5.093542e+04  1.073520e+09  1.479353e+09  2.530748e+04
# std         0.213597  1.226416e+06  6.194657e+08  7.268419e+07  9.157989e+05
# min         0.009327  1.000000e-02  1.852000e+04  1.240920e+09  0.000000e+00
# 25%         1.000000  1.500000e+03  5.368643e+08  1.425915e+09  1.300000e+02
# 50%         1.000000  5.000000e+03  1.073560e+09  1.480564e+09  1.675000e+03
# 75%         1.000000  1.500000e+04  1.610402e+09  1.546214e+09  7.341000e+03
# max         1.226759  1.000000e+08  2.147476e+09  1.589431e+09  2.353205e+08
#
#        state_changed_at  static_usd_rate   usd_pledged
# count      2.170060e+05    217006.000000  2.170060e+05
# mean       1.482044e+09         1.001748  1.392965e+04
# std        7.257796e+07         0.239873  1.116816e+05
# min        1.242468e+09         0.008771  0.000000e+00
# 25%        1.428638e+09         1.000000  1.250000e+02
# 50%        1.483394e+09         1.000000  1.631000e+03
# 75%        1.549039e+09         1.000000  6.831308e+03
# max        1.589432e+09         1.716408  1.296961e+07

# %% [markdown]
# ### Observations

# %% [markdown]
# At the time of this writing, no data dictionary can be found so I have to make some assumptions as to what some of these features are based on research on the terms. For terms that I cannot explain, they will likely be removed unless they provide substantial meaning.
#
# After all of the missing values were removed, 34 columns remained:
#
# ||Feature|Data Type|Description|
# |--------|--------|--------|-------|
# |1|Backers count|integer|number of backers supporting the project|
# |2|Blurb| text|text that describes the project|
# |3|Category|object|a string of text that includes the project ID, the 'name' of the project, 'slug' which includes the name and the broader category that the project falls into, position number, parent id, parent name (the broader category), color number, and the url|
# |4|Converted pledged amount|integer| -------------- |
# |5|Country|nominal| --------------|
# |6|Country displayable name|nominal|----------------|
# |7|Created at|timestamp| ----------------|
# |8|Creator|object|a string of text that includes the project ID, the 'name' of the project, 'slug' which includes the name and the broader category that the project falls into, position number, parent id, parent name (the broader category), color number, and the url|
# |9|Currency|nominal| ----------------|
# |10|Currency symbol|nominal| the symbol for the type of currency|
# |11|Currency trailing code|boolean| ----------|
# |12|Current currency|object|------------|
# |13|Deadline|integer|--------|
# |14|Disable communication|boolean|----------------------|
# |15|FX_rate|float|-----------|
# |16|Goal|float|--------------|
# |17|ID|integer| number of backers supporting the project|
# |18|Is starrable|integer| number of backers supporting the project|
# |19|Launched at|integer| number of backers supporting the project|
# |20|Location|integer| number of backers supporting the project|
# |21|Name|integer| number of backers supporting the project|
# |22|Photo|integer| number of backers supporting the project|
# |23|Pledged|integer| number of backers supporting the project|
# |24|Profile|integer| number of backers supporting the project|
# |25|Slug|integer| number of backers supporting the project|
# |26|Source url|integer| number of backers supporting the project|
# |27|Spotlight|integer| number of backers supporting the project|
# |28|Staff pick|integer| number of backers supporting the project|
# |29|State|nominal| number of backers supporting the project|
# |30|State changed at|integer| number of backers supporting the project|
# |31|Static usd rate|integer| number of backers supporting the project|
# |32|Urls|integer| number of backers supporting the project|
# |33|USD pledged|integer| number of backers supporting the project|
# |34|USD type|integer| number of backers supporting the project|

# %% [markdown]
# ### Value Counts

# %%
df.columns
# Out:
# Index(['backers_count', 'blurb', 'category', 'converted_pledged_amount',
#        'country', 'country_displayable_name', 'created_at', 'creator',
#        'currency', 'currency_symbol', 'currency_trailing_code',
#        'current_currency', 'deadline', 'disable_communication', 'fx_rate',
#        'goal', 'id', 'is_starrable', 'launched_at', 'location', 'name',
#        'photo', 'pledged', 'profile', 'slug', 'source_url', 'spotlight',
#        'staff_pick', 'state', 'state_changed_at', 'static_usd_rate', 'urls',
#        'usd_pledged', 'usd_type'],
#       dtype='object')

# %%
df.creator.value_counts()
# Out:
# {"id":2053011023,"name":"Benjamin Hennessey","slug":"combatmedallions","is_registered":null,"chosen_currency":null,"is_superbacker":null,"avatar":{"thumb":"https://ksr-ugc.imgix.net/assets/008/647/822/59acad1fb0a00a22cd0c5df2db43343f_original.jpg?ixlib=rb-2.1.0&w=40&h=40&fit=crop&v=1461536749&auto=format&frame=1&q=92&s=681661727d91252651719bdc7202b454","small":"https://ksr-ugc.imgix.net/assets/008/647/822/59acad1fb0a00a22cd0c5df2db43343f_original.jpg?ixlib=rb-2.1.0&w=160&h=160&fit=crop&v=1461536749&auto=format&frame=1&q=92&s=119a85455aafb64c83a17e481c02a595","medium":"https://ksr-ugc.imgix.net/assets/008/647/822/59acad1fb0a00a22cd0c5df2db43343f_original.jpg?ixlib=rb-2.1.0&w=160&h=160&fit=crop&v=1461536749&auto=format&frame=1&q=92&s=119a85455aafb64c83a17e481c02a595"},"urls":{"web":{"user":"https://www.kickstarter.com/profile/combatmedallions"},"api":{"user":"https://api.kickstarter.com/v1/users/2053011023?signature=1589516310.c7ebe463c5a4b9915638287eb55c3dbe464dffc5"}}}    12
# {"id":1712814392,"name":"Amanda B","is_registered":null,"chosen_currency":null,"is_superbacker":null,"avatar":{"thumb":"https://ksr-ugc.imgix.net/assets/009/821/337/76442e6111170eeb2b08c3958fd2b2c7_original.jpg?ixlib=rb-2.1.0&w=40&h=40&fit=crop&v=1483961513&auto=format&frame=1&q=92&s=f17f2b4e51e9e7043ef57b9890b33e54","small":"https://ksr-ugc.imgix.net/assets/009/821/337/76442e6111170eeb2b08c3958fd2b2c7_original.jpg?ixlib=rb-2.1.0&w=160&h=160&fit=crop&v=1483961513&auto=format&frame=1&q=92&s=2a3cf4b664c5f10c59e187842ee48acc","medium":"https://ksr-ugc.imgix.net/assets/009/821/337/76442e6111170eeb2b08c3958fd2b2c7_original.jpg?ixlib=rb-2.1.0&w=160&h=160&fit=crop&v=1483961513&auto=format&frame=1&q=92&s=2a3cf4b664c5f10c59e187842ee48acc"},"urls":{"web":{"user":"https://www.kickstarter.com/profile/1712814392"},"api":{"user":"https://api.kickstarter.com/v1/users/1712814392?signature=1589516561.1b852d0c529d8d0ba83fd4697dd2846ca58ea2fc"}}}                                               7
# {"id":1383111647,"name":"Tom And Gary","slug":"theddp","is_registered":null,"chosen_currency":null,"is_superbacker":null,"avatar":{"thumb":"https://ksr-ugc.imgix.net/assets/005/844/631/f1c717e9cd8e77f998ce1fbeee610014_original.jpeg?ixlib=rb-2.1.0&w=40&h=40&fit=crop&v=1461088606&auto=format&frame=1&q=92&s=c744211d16cff7011c5691e717775ce9","small":"https://ksr-ugc.imgix.net/assets/005/844/631/f1c717e9cd8e77f998ce1fbeee610014_original.jpeg?ixlib=rb-2.1.0&w=160&h=160&fit=crop&v=1461088606&auto=format&frame=1&q=92&s=84f2af87ec98ed0ca79771be79b3d3ac","medium":"https://ksr-ugc.imgix.net/assets/005/844/631/f1c717e9cd8e77f998ce1fbeee610014_original.jpeg?ixlib=rb-2.1.0&w=160&h=160&fit=crop&v=1461088606&auto=format&frame=1&q=92&s=84f2af87ec98ed0ca79771be79b3d3ac"},"urls":{"web":{"user":"https://www.kickstarter.com/profile/theddp"},"api":{"user":"https://api.kickstarter.com/v1/users/1383111647?signature=1589516066.d55432e738b70a06276c4d0e2770a577efc2a019"}}}                            5
# {"id":1383111647,"name":"Tom And Gary","slug":"theddp","is_registered":null,"chosen_currency":null,"is_superbacker":null,"avatar":{"thumb":"https://ksr-ugc.imgix.net/assets/005/844/631/f1c717e9cd8e77f998ce1fbeee610014_original.jpeg?ixlib=rb-2.1.0&w=40&h=40&fit=crop&v=1461088606&auto=format&frame=1&q=92&s=c744211d16cff7011c5691e717775ce9","small":"https://ksr-ugc.imgix.net/assets/005/844/631/f1c717e9cd8e77f998ce1fbeee610014_original.jpeg?ixlib=rb-2.1.0&w=160&h=160&fit=crop&v=1461088606&auto=format&frame=1&q=92&s=84f2af87ec98ed0ca79771be79b3d3ac","medium":"https://ksr-ugc.imgix.net/assets/005/844/631/f1c717e9cd8e77f998ce1fbeee610014_original.jpeg?ixlib=rb-2.1.0&w=160&h=160&fit=crop&v=1461088606&auto=format&frame=1&q=92&s=84f2af87ec98ed0ca79771be79b3d3ac"},"urls":{"web":{"user":"https://www.kickstarter.com/profile/theddp"},"api":{"user":"https://api.kickstarter.com/v1/users/1383111647?signature=1589516065.067caa57d937078025232a3c387380b6ba31b297"}}}                            5
# {"id":1925511685,"name":"Riley Fanning","is_registered":null,"chosen_currency":null,"is_superbacker":null,"avatar":{"thumb":"https://ksr-ugc.imgix.net/assets/019/909/097/8d5249cb40a5ace249a46e2f26561646_original.jpeg?ixlib=rb-2.1.0&w=40&h=40&fit=crop&v=1517445719&auto=format&frame=1&q=92&s=257929828cb8432dd61c5bd4d22756fc","small":"https://ksr-ugc.imgix.net/assets/019/909/097/8d5249cb40a5ace249a46e2f26561646_original.jpeg?ixlib=rb-2.1.0&w=160&h=160&fit=crop&v=1517445719&auto=format&frame=1&q=92&s=7dc2b236c844678e0f485cd5396defe0","medium":"https://ksr-ugc.imgix.net/assets/019/909/097/8d5249cb40a5ace249a46e2f26561646_original.jpeg?ixlib=rb-2.1.0&w=160&h=160&fit=crop&v=1517445719&auto=format&frame=1&q=92&s=7dc2b236c844678e0f485cd5396defe0"},"urls":{"web":{"user":"https://www.kickstarter.com/profile/1925511685"},"api":{"user":"https://api.kickstarter.com/v1/users/1925511685?signature=1589518413.0e40be9e2ac208b32e9dc9121f076ec2a431d966"}}}                                       5
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ..
# {"id":859565924,"name":"Rick Parker","slug":"rickparker","is_registered":null,"chosen_currency":null,"is_superbacker":null,"avatar":{"thumb":"https://ksr-ugc.imgix.net/assets/006/058/725/ed599bcd6591fa9234b9c40bd7b0787d_original.jpg?ixlib=rb-2.1.0&w=40&h=40&fit=crop&v=1461363855&auto=format&frame=1&q=92&s=f546ad063489c2b55e933d522f477b45","small":"https://ksr-ugc.imgix.net/assets/006/058/725/ed599bcd6591fa9234b9c40bd7b0787d_original.jpg?ixlib=rb-2.1.0&w=160&h=160&fit=crop&v=1461363855&auto=format&frame=1&q=92&s=c53adbdc7862969737fe974efa22cdbe","medium":"https://ksr-ugc.imgix.net/assets/006/058/725/ed599bcd6591fa9234b9c40bd7b0787d_original.jpg?ixlib=rb-2.1.0&w=160&h=160&fit=crop&v=1461363855&auto=format&frame=1&q=92&s=c53adbdc7862969737fe974efa22cdbe"},"urls":{"web":{"user":"https://www.kickstarter.com/profile/rickparker"},"api":{"user":"https://api.kickstarter.com/v1/users/859565924?signature=1589513521.8010ff98a49f16ed20d045e736a0af3620c308f7"}}}                          1
# {"id":103203953,"name":"David Nehmzow","is_registered":null,"chosen_currency":null,"is_superbacker":null,"avatar":{"thumb":"https://ksr-ugc.imgix.net/assets/009/778/409/54e255eaff364727b0c707ed2650bee1_original.jpg?ixlib=rb-2.1.0&w=40&h=40&fit=crop&v=1461634168&auto=format&frame=1&q=92&s=04c0d888431f77d97fd1b1a615edd84d","small":"https://ksr-ugc.imgix.net/assets/009/778/409/54e255eaff364727b0c707ed2650bee1_original.jpg?ixlib=rb-2.1.0&w=160&h=160&fit=crop&v=1461634168&auto=format&frame=1&q=92&s=385df6cb510e5169b345f81a9157b54a","medium":"https://ksr-ugc.imgix.net/assets/009/778/409/54e255eaff364727b0c707ed2650bee1_original.jpg?ixlib=rb-2.1.0&w=160&h=160&fit=crop&v=1461634168&auto=format&frame=1&q=92&s=385df6cb510e5169b345f81a9157b54a"},"urls":{"web":{"user":"https://www.kickstarter.com/profile/103203953"},"api":{"user":"https://api.kickstarter.com/v1/users/103203953?signature=1589522878.76775c3605319d2e97974e891b1d1fbc0b7313f1"}}}                                             1
# {"id":1734367642,"name":"QB Darla","slug":"wittypublications","is_registered":null,"chosen_currency":null,"is_superbacker":null,"avatar":{"thumb":"https://ksr-ugc.imgix.net/assets/026/044/024/c96e3689e3e34dcdd6ed628c50c021be_original.jpg?ixlib=rb-2.1.0&w=40&h=40&fit=crop&v=1565055077&auto=format&frame=1&q=92&s=17de918d72717ec68541bcabce375fcd","small":"https://ksr-ugc.imgix.net/assets/026/044/024/c96e3689e3e34dcdd6ed628c50c021be_original.jpg?ixlib=rb-2.1.0&w=160&h=160&fit=crop&v=1565055077&auto=format&frame=1&q=92&s=cc02484cde131b20515cbd4539db10e3","medium":"https://ksr-ugc.imgix.net/assets/026/044/024/c96e3689e3e34dcdd6ed628c50c021be_original.jpg?ixlib=rb-2.1.0&w=160&h=160&fit=crop&v=1565055077&auto=format&frame=1&q=92&s=cc02484cde131b20515cbd4539db10e3"},"urls":{"web":{"user":"https://www.kickstarter.com/profile/wittypublications"},"api":{"user":"https://api.kickstarter.com/v1/users/1734367642?signature=1589521072.ef06fe0fe59d26fbd83738e19105f34506e5ddff"}}}             1
# {"id":1684372505,"name":"Javier Lazaga","is_registered":null,"chosen_currency":null,"is_superbacker":null,"avatar":{"thumb":"https://ksr-ugc.imgix.net/assets/018/245/738/993872f52d76e3af2013c061f2fd0bb4_original.jpg?ixlib=rb-2.1.0&w=40&h=40&fit=crop&v=1504874234&auto=format&frame=1&q=92&s=2df50a6aa4690a28d3062b0ca908c25c","small":"https://ksr-ugc.imgix.net/assets/018/245/738/993872f52d76e3af2013c061f2fd0bb4_original.jpg?ixlib=rb-2.1.0&w=160&h=160&fit=crop&v=1504874234&auto=format&frame=1&q=92&s=46eaa2761d24d02e41935e3f43ff5453","medium":"https://ksr-ugc.imgix.net/assets/018/245/738/993872f52d76e3af2013c061f2fd0bb4_original.jpg?ixlib=rb-2.1.0&w=160&h=160&fit=crop&v=1504874234&auto=format&frame=1&q=92&s=46eaa2761d24d02e41935e3f43ff5453"},"urls":{"web":{"user":"https://www.kickstarter.com/profile/1684372505"},"api":{"user":"https://api.kickstarter.com/v1/users/1684372505?signature=1589522010.ea9fc206fb1e961d95da39116ad4b5b7c34f1f20"}}}                                          1
# {"id":1792811760,"name":"Bogdan Gogotov","is_registered":null,"chosen_currency":null,"is_superbacker":null,"avatar":{"thumb":"https://ksr-ugc.imgix.net/assets/011/825/416/29bbca7d71a3707d98c1445520a4f903_original.jpg?ixlib=rb-2.1.0&w=40&h=40&fit=crop&v=1463700169&auto=format&frame=1&q=92&s=174d5ea9fc90ac914013c1507a43889e","small":"https://ksr-ugc.imgix.net/assets/011/825/416/29bbca7d71a3707d98c1445520a4f903_original.jpg?ixlib=rb-2.1.0&w=160&h=160&fit=crop&v=1463700169&auto=format&frame=1&q=92&s=d23c48b134cc2ce95565fd6da0614a60","medium":"https://ksr-ugc.imgix.net/assets/011/825/416/29bbca7d71a3707d98c1445520a4f903_original.jpg?ixlib=rb-2.1.0&w=160&h=160&fit=crop&v=1463700169&auto=format&frame=1&q=92&s=d23c48b134cc2ce95565fd6da0614a60"},"urls":{"web":{"user":"https://www.kickstarter.com/profile/1792811760"},"api":{"user":"https://api.kickstarter.com/v1/users/1792811760?signature=1589513738.0a072ecdb5096bdd10af6d2e62645e8d4d7a59f3"}}}                                         1
# Name: creator, Length: 216365, dtype: int64

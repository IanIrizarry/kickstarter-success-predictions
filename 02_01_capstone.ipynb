# %% [markdown]
# # Capstone Project

# %% [markdown]
# ## Part 1: Topic Proposal

# %% [markdown]
# ### Creating a Popular Board Game

# %% [markdown]
# #### Problem Statement

# %% [markdown]
# Can a recommender program recommend what characteristics would lead to a successful board game on Kickstarter?

# %% [markdown]
# #### Description of goals

# %% [markdown]
# In this analysis, the goal would be to use a recommender program to create a game that will result in a successful kickstarter program.

# %% [markdown]
# #### Criteria for success

# %% [markdown]
# This will be a successful project if I am able to first, determine whether I can predict what board games are the most popular on Kickstarter based on certain criteria and then second, create a game that becomes popular on Kickstarter.

# %% [markdown]
# #### Audience

# %% [markdown]
# This project's audience will be entrepreneurs and game enthusiasts.

# %% [markdown]
# #### Potential datasets

# %% [markdown]
# 1. There is a website that has scraped several years of Kickstarter data
# 2. I will likely scrape from multiple websites the most popular mechanics for games.

# %% [markdown]
# Goal:
#
# Describe your proposed problem statement and approach, summarize your initial EDA/data collection, and perform your initial EDA in a Jupyter notebook on *your personal GitHub* with a link submitted to your instructors on Google Classroom.
#
# Overview:
#
# In this section you will update us on your project, including the project you have chosen, your problem statement, an extensive outline of EDA and modeling to date, the goal of your predictive model, and the data you will use to explore that model.
#
# Your data must be fully in hand by this point OR you must have a solid, achievable plan to do so that has been communicated to your instructors.
#
# Requirements:
#
# We expect a formatted and complete Jupyter notebook hosted on your personal (*not* GA) GitHub by EOD on Monday June 22, 2020, which accomplishes the following:
#
# - Identifies which of the three proposals you outlined in your lightning talk you have chosen
# - Articulates the main goal of your project (your problem statement)
# - Outlines your proposed methods and models
# - Defines the risks & assumptions of your data
# - Revises initial goals & success criteria, as needed
# - Documents your data source
# - Performs & summarizes preliminary EDA of your data

# %%
import os
import glob
import pandas as pd
os.chdir("./datasets/kickstarter_data/")

# %%
## credit: https://www.freecodecamp.org/news/how-to-combine-multiple-csv-files-with-8-lines-of-code-265183e0854/
# extension = 'csv'
# all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# #combine all files in the list
# combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# #export to csv
# combined_csv.to_csv( "combined.csv", index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv('combined.csv')
df.head()
# Out:
#    backers_count                                              blurb  \
# 0              1  we are going Production herbal teabag of  plan...
# 1            637  Two agents battle each other in another dimens...
# 2             50  A collection of Hard Enamel pins inspired by T...
# 3              8  Low carb, no sugar sauces and marinades using ...
# 4           6452  The everyday bag fused with Parisian chic and ...
#
#                                             category  \
# 0  {"id":313,"name":"Small Batch","slug":"food/sm...
# 1  {"id":34,"name":"Tabletop Games","slug":"games...
# 2  {"id":262,"name":"Accessories","slug":"fashion...
# 3  {"id":313,"name":"Small Batch","slug":"food/sm...
# 4  {"id":28,"name":"Product Design","slug":"desig...
#
#    converted_pledged_amount country country_displayable_name  created_at  \
# 0                        19      AU                Australia  1441269202
# 1                     16233      US        the United States  1576048498
# 2                       983      CA                   Canada  1560821709
# 3                       361      US        the United States  1563139848
# 4                   1385803      US        the United States  1561364892
#
#                                              creator currency currency_symbol  \
# 0  {"id":1555219532,"name":"ehsan","is_registered...      AUD               $
# 1  {"id":99575233,"name":"David Gerrard","is_regi...      USD               $
# 2  {"id":1855173855,"name":"Caitlin Peters","slug...      CAD               $
# 3  {"id":1148188586,"name":"Ian","slug":"penningt...      USD               $
# 4  {"id":1085606247,"name":"Laflore","slug":"bobo...      USD               $
#
#    ...                                               slug  \
# 0  ...  production-herbal-teabag-of-plants-native-to-iran
# 1  ...                                      slip-strike-0
# 2  ...                                  tattoo-shop-flash
# 3  ...              penningtons-keto-sauces-and-marinades
# 4  ...          bobobark-designed-for-women-made-for-life
#
#                                           source_url  spotlight  staff_pick  \
# 0  https://www.kickstarter.com/discover/categorie...      False       False
# 1  https://www.kickstarter.com/discover/categorie...       True       False
# 2  https://www.kickstarter.com/discover/categorie...       True       False
# 3  https://www.kickstarter.com/discover/categorie...      False       False
# 4  https://www.kickstarter.com/discover/categorie...       True       False
#
#         state  state_changed_at  static_usd_rate  \
# 0      failed        1444141184         0.691164
# 1  successful        1583987400         1.000000
# 2  successful        1564165825         0.762900
# 3      failed        1569530544         1.000000
# 4  successful        1568408340         1.000000
#
#                                                 urls   usd_pledged  usd_type
# 0  {"web":{"project":"https://www.kickstarter.com...  1.866144e+01  domestic
# 1  {"web":{"project":"https://www.kickstarter.com...  1.623300e+04  domestic
# 2  {"web":{"project":"https://www.kickstarter.com...  9.874137e+02  domestic
# 3  {"web":{"project":"https://www.kickstarter.com...  3.610000e+02  domestic
# 4  {"web":{"project":"https://www.kickstarter.com...  1.385803e+06  domestic
#
# [5 rows x 38 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217433 entries, 0 to 217432
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   backers_count             217433 non-null  int64
#  1   blurb                     217425 non-null  object
#  2   category                  217433 non-null  object
#  3   converted_pledged_amount  217433 non-null  int64
#  4   country                   217433 non-null  object
#  5   country_displayable_name  217433 non-null  object
#  6   created_at                217433 non-null  int64
#  7   creator                   217433 non-null  object
#  8   currency                  217433 non-null  object
#  9   currency_symbol           217433 non-null  object
#  10  currency_trailing_code    217433 non-null  bool
#  11  current_currency          217433 non-null  object
#  12  deadline                  217433 non-null  int64
#  13  disable_communication     217433 non-null  bool
#  14  friends                   72 non-null      object
#  15  fx_rate                   217433 non-null  float64
#  16  goal                      217433 non-null  float64
#  17  id                        217433 non-null  int64
#  18  is_backing                72 non-null      object
#  19  is_starrable              217433 non-null  bool
#  20  is_starred                72 non-null      object
#  21  launched_at               217433 non-null  int64
#  22  location                  217218 non-null  object
#  23  name                      217433 non-null  object
#  24  permissions               72 non-null      object
#  25  photo                     217433 non-null  object
#  26  pledged                   217433 non-null  float64
#  27  profile                   217433 non-null  object
#  28  slug                      217433 non-null  object
#  29  source_url                217433 non-null  object
#  30  spotlight                 217433 non-null  bool
#  31  staff_pick                217433 non-null  bool
#  32  state                     217433 non-null  object
#  33  state_changed_at          217433 non-null  int64
#  34  static_usd_rate           217433 non-null  float64
#  35  urls                      217433 non-null  object
#  36  usd_pledged               217433 non-null  float64
#  37  usd_type                  217229 non-null  object
# dtypes: bool(5), float64(5), int64(7), object(21)
# memory usage: 55.8+ MB

# %%
df.category.str.split(',')
# Out:
# 0         [{"id":313, "name":"Small Batch", "slug":"food...
# 1         [{"id":34, "name":"Tabletop Games", "slug":"ga...
# 2         [{"id":262, "name":"Accessories", "slug":"fash...
# 3         [{"id":313, "name":"Small Batch", "slug":"food...
# 4         [{"id":28, "name":"Product Design", "slug":"de...
#                                 ...
# 217428    [{"id":13, "name":"Journalism", "slug":"journa...
# 217429    [{"id":277, "name":"Nature", "slug":"photograp...
# 217430    [{"id":52, "name":"Hardware", "slug":"technolo...
# 217431    [{"id":307, "name":"Drinks", "slug":"food/drin...
# 217432    [{"id":258, "name":"Architecture", "slug":"des...
# Name: category, Length: 217433, dtype: object

# %%
df.category.str.split(':')
# Out:
# 0         [{"id", 313,"name", "Small Batch","slug", "foo...
# 1         [{"id", 34,"name", "Tabletop Games","slug", "g...
# 2         [{"id", 262,"name", "Accessories","slug", "fas...
# 3         [{"id", 313,"name", "Small Batch","slug", "foo...
# 4         [{"id", 28,"name", "Product Design","slug", "d...
#                                 ...
# 217428    [{"id", 13,"name", "Journalism","slug", "journ...
# 217429    [{"id", 277,"name", "Nature","slug", "photogra...
# 217430    [{"id", 52,"name", "Hardware","slug", "technol...
# 217431    [{"id", 307,"name", "Drinks","slug", "food/dri...
# 217432    [{"id", 258,"name", "Architecture","slug", "de...
# Name: category, Length: 217433, dtype: object

# %%
df.corr()
# Out:
#                           backers_count  converted_pledged_amount  created_at  \
# backers_count                  1.000000                  0.796269    0.044160
# converted_pledged_amount       0.796269                  1.000000    0.038041
# created_at                     0.044160                  0.038041    1.000000
# currency_trailing_code         0.011253                  0.013555   -0.166883
# deadline                       0.048626                  0.041907    0.986535
# disable_communication               NaN                       NaN         NaN
# fx_rate                       -0.001494                  0.000234   -0.090553
# goal                           0.011092                  0.010006    0.002338
# id                            -0.001067                 -0.001896   -0.001614
# is_starrable                   0.005910                  0.003982    0.225170
# launched_at                    0.048571                  0.041651    0.986690
# pledged                        0.202854                  0.203503    0.018110
# spotlight                      0.115542                  0.089710    0.028742
# staff_pick                     0.147338                  0.124877   -0.030163
# state_changed_at               0.048835                  0.042076    0.986496
# static_usd_rate               -0.007335                 -0.006712   -0.123077
# usd_pledged                    0.796088                  0.999935    0.038013
#
#                           currency_trailing_code  deadline  \
# backers_count                           0.011253  0.048626
# converted_pledged_amount                0.013555  0.041907
# created_at                             -0.166883  0.986535
# currency_trailing_code                  1.000000 -0.163362
# deadline                               -0.163362  1.000000
# disable_communication                        NaN       NaN
# fx_rate                                -0.391075 -0.089952
# goal                                   -0.002633  0.003031
# id                                      0.005300 -0.001116
# is_starrable                           -0.044349  0.229351
# launched_at                            -0.163263  0.999896
# pledged                                -0.012693  0.019075
# spotlight                               0.023707  0.030754
# staff_pick                              0.009232 -0.023470
# state_changed_at                       -0.163260  0.999956
# static_usd_rate                        -0.543039 -0.124356
# usd_pledged                             0.013484  0.041884
#
#                           disable_communication   fx_rate      goal        id  \
# backers_count                               NaN -0.001494  0.011092 -0.001067
# converted_pledged_amount                    NaN  0.000234  0.010006 -0.001896
# created_at                                  NaN -0.090553  0.002338 -0.001614
# currency_trailing_code                      NaN -0.391075 -0.002633  0.005300
# deadline                                    NaN -0.089952  0.003031 -0.001116
# disable_communication                       NaN       NaN       NaN       NaN
# fx_rate                                     NaN  1.000000 -0.038095 -0.001354
# goal                                        NaN -0.038095  1.000000  0.001349
# id                                          NaN -0.001354  0.001349  1.000000
# is_starrable                                NaN -0.004373  0.000132 -0.005013
# launched_at                                 NaN -0.089432  0.002590 -0.001117
# pledged                                     NaN -0.053011  0.068371 -0.001441
# spotlight                                   NaN  0.019383 -0.035551  0.001608
# staff_pick                                  NaN  0.000156 -0.004182  0.003511
# state_changed_at                            NaN -0.089965  0.002864 -0.001082
# static_usd_rate                             NaN  0.902261 -0.036774 -0.001952
# usd_pledged                                 NaN -0.000738  0.010051 -0.001909
#
#                           is_starrable  launched_at   pledged  spotlight  \
# backers_count                 0.005910     0.048571  0.202854   0.115542
# converted_pledged_amount      0.003982     0.041651  0.203503   0.089710
# created_at                    0.225170     0.986690  0.018110   0.028742
# currency_trailing_code       -0.044349    -0.163263 -0.012693   0.023707
# deadline                      0.229351     0.999896  0.019075   0.030754
# disable_communication              NaN          NaN       NaN        NaN
# fx_rate                      -0.004373    -0.089432 -0.053011   0.019383
# goal                          0.000132     0.002590  0.068371  -0.035551
# id                           -0.005013    -0.001117 -0.001441   0.001608
# is_starrable                  1.000000     0.228254  0.001531  -0.181931
# launched_at                   0.228254     1.000000  0.019048   0.033355
# pledged                       0.001531     0.019048  1.000000   0.019881
# spotlight                    -0.181931     0.033355  0.019881   1.000000
# staff_pick                   -0.021474    -0.023022  0.028976   0.244873
# state_changed_at              0.222940     0.999876  0.019124   0.033296
# static_usd_rate              -0.041101    -0.123792 -0.052026   0.011587
# usd_pledged                   0.003583     0.041627  0.202646   0.089853
#
#                           staff_pick  state_changed_at  static_usd_rate  \
# backers_count               0.147338          0.048835        -0.007335
# converted_pledged_amount    0.124877          0.042076        -0.006712
# created_at                 -0.030163          0.986496        -0.123077
# currency_trailing_code      0.009232         -0.163260        -0.543039
# deadline                   -0.023470          0.999956        -0.124356
# disable_communication            NaN               NaN              NaN
# fx_rate                     0.000156         -0.089965         0.902261
# goal                       -0.004182          0.002864        -0.036774
# id                          0.003511         -0.001082        -0.001952
# is_starrable               -0.021474          0.222940        -0.041101
# launched_at                -0.023022          0.999876        -0.123792
# pledged                     0.028976          0.019124        -0.052026
# spotlight                   0.244873          0.033296         0.011587
# staff_pick                  1.000000         -0.022989        -0.000672
# state_changed_at           -0.022989          1.000000        -0.124240
# static_usd_rate            -0.000672         -0.124240         1.000000
# usd_pledged                 0.124832          0.042054        -0.006676
#
#                           usd_pledged
# backers_count                0.796088
# converted_pledged_amount     0.999935
# created_at                   0.038013
# currency_trailing_code       0.013484
# deadline                     0.041884
# disable_communication             NaN
# fx_rate                     -0.000738
# goal                         0.010051
# id                          -0.001909
# is_starrable                 0.003583
# launched_at                  0.041627
# pledged                      0.202646
# spotlight                    0.089853
# staff_pick                   0.124832
# state_changed_at             0.042054
# static_usd_rate             -0.006676
# usd_pledged                  1.000000

# %%
df.state.value_counts()
# Out:
# successful    127093
# failed         76260
# canceled        9029
# live            5051
# Name: state, dtype: int64

# %%
df.state = df.state.astype('category')

# %%
df.state
# Out:
# 0             failed
# 1         successful
# 2         successful
# 3             failed
# 4         successful
#              ...
# 217428    successful
# 217429        failed
# 217430        failed
# 217431        failed
# 217432        failed
# Name: state, Length: 217433, dtype: category
# Categories (4, object): [canceled, failed, live, successful]

# %%
df.dtypes
# Out:
# backers_count                  int64
# blurb                         object
# category                      object
# converted_pledged_amount       int64
# country                       object
# country_displayable_name      object
# created_at                     int64
# creator                       object
# currency                      object
# currency_symbol               object
# currency_trailing_code          bool
# current_currency              object
# deadline                       int64
# disable_communication           bool
# friends                       object
# fx_rate                      float64
# goal                         float64
# id                             int64
# is_backing                    object
# is_starrable                    bool
# is_starred                    object
# launched_at                    int64
# location                      object
# name                          object
# permissions                   object
# photo                         object
# pledged                      float64
# profile                       object
# slug                          object
# source_url                    object
# spotlight                       bool
# staff_pick                      bool
# state                       category
# state_changed_at               int64
# static_usd_rate              float64
# urls                          object
# usd_pledged                  float64
# usd_type                      object
# dtype: object

# %%
df.state.value_counts()
# Out:
# successful    127093
# failed         76260
# canceled        9029
# live            5051
# Name: state, dtype: int64

# %%
df.category = df.category.str.replace('"','').split('\n')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-5d76bc6cf201> in <module>
# ----> 1 df.category = df.category.str.replace('"','').split('\n')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'
